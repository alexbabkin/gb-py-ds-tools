# %% [markdown]
# # TASK 1

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = ['svg']

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]

# %%
plt.plot(x, y)
plt.show()

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# # TASK 2

# %%
t = np.linspace(0, 10, 51)
t
# Out:
# array([ 0. ,  0.2,  0.4,  0.6,  0.8,  1. ,  1.2,  1.4,  1.6,  1.8,  2. ,
#         2.2,  2.4,  2.6,  2.8,  3. ,  3.2,  3.4,  3.6,  3.8,  4. ,  4.2,
#         4.4,  4.6,  4.8,  5. ,  5.2,  5.4,  5.6,  5.8,  6. ,  6.2,  6.4,
#         6.6,  6.8,  7. ,  7.2,  7.4,  7.6,  7.8,  8. ,  8.2,  8.4,  8.6,
#         8.8,  9. ,  9.2,  9.4,  9.6,  9.8, 10. ])

# %%
f = np.cos(t)
f
# Out:
# array([0.54030231, 0.55696725, 0.60497569, 0.6783104 , 0.76695963,
#        0.85755322, 0.93506365, 0.98559033, 0.99957372, 0.97430044,
#        0.91465333, 0.83177367, 0.74022343, 0.65479214, 0.5879919 ,
#        0.54869613, 0.54173642, 0.56793775, 0.62414592, 0.70315757,
#        0.79387345, 0.88221008, 0.95314381, 0.99371749, 0.99617441,
#        0.96003693, 0.89223909, 0.80525384, 0.71402497, 0.63288735,
#        0.57338048, 0.54320879, 0.54602441, 0.58149388, 0.64528695,
#        0.72902338, 0.82059138, 0.90536946, 0.96859996, 0.99854476,
#        0.98943353, 0.94303617, 0.86817241, 0.77837691, 0.68870637,
#        0.61285301, 0.56129748, 0.54056058, 0.55312319, 0.59749222,
#        0.66815392])

# %%
plt.plot(t, f)
plt.title('График f(t)')
plt.xlabel('Значения t')
plt.ylabel('Значения f')
plt.axis([0.5, 9.5, -2.5, 2.5])
plt.show()

# %% [markdown]
# # TASK 3

# %%
t = np.linspace(-3, 3, 51)
t
# Out:
# array([-3.  , -2.88, -2.76, -2.64, -2.52, -2.4 , -2.28, -2.16, -2.04,
#        -1.92, -1.8 , -1.68, -1.56, -1.44, -1.32, -1.2 , -1.08, -0.96,
#        -0.84, -0.72, -0.6 , -0.48, -0.36, -0.24, -0.12,  0.  ,  0.12,
#         0.24,  0.36,  0.48,  0.6 ,  0.72,  0.84,  0.96,  1.08,  1.2 ,
#         1.32,  1.44,  1.56,  1.68,  1.8 ,  1.92,  2.04,  2.16,  2.28,
#         2.4 ,  2.52,  2.64,  2.76,  2.88,  3.  ])

# %%
y1 = x ** 2
y1
# Out:
# array([ 0.5,  0.9,  1.3,  1.7,  2.1,  2.5,  2.9,  3.3,  3.7,  4.1,  4.5,
#         4.9,  5.3,  5.7,  6.1,  6.5,  6.9,  7.3,  7.7,  8.1,  8.5,  8.9,
#         9.3,  9.7, 10.1, 10.5, 10.9, 11.3, 11.7, 12.1, 12.5, 12.9, 13.3,
#        13.7, 14.1, 14.5, 14.9, 15.3, 15.7, 16.1, 16.5, 16.9, 17.3, 17.7,
#        18.1, 18.5, 18.9, 19.3, 19.7, 20.1, 20.5])

# %%
y2 = 2 * x + 0.5
y2
# Out:
# array([ 0.5,  0.9,  1.3,  1.7,  2.1,  2.5,  2.9,  3.3,  3.7,  4.1,  4.5,
#         4.9,  5.3,  5.7,  6.1,  6.5,  6.9,  7.3,  7.7,  8.1,  8.5,  8.9,
#         9.3,  9.7, 10.1, 10.5, 10.9, 11.3, 11.7, 12.1, 12.5, 12.9, 13.3,
#        13.7, 14.1, 14.5, 14.9, 15.3, 15.7, 16.1, 16.5, 16.9, 17.3, 17.7,
#        18.1, 18.5, 18.9, 19.3, 19.7, 20.1, 20.5])

# %%
y3 = -3 * x - 1.5
y3
# Out:
# array([ -1.5,  -2.1,  -2.7,  -3.3,  -3.9,  -4.5,  -5.1,  -5.7,  -6.3,
#         -6.9,  -7.5,  -8.1,  -8.7,  -9.3,  -9.9, -10.5, -11.1, -11.7,
#        -12.3, -12.9, -13.5, -14.1, -14.7, -15.3, -15.9, -16.5, -17.1,
#        -17.7, -18.3, -18.9, -19.5, -20.1, -20.7, -21.3, -21.9, -22.5,
#        -23.1, -23.7, -24.3, -24.9, -25.5, -26.1, -26.7, -27.3, -27.9,
#        -28.5, -29.1, -29.7, -30.3, -30.9, -31.5])

# %%
y4 = np.sin(x)
y4
# Out:
# array([ 0.        ,  0.19866933,  0.38941834,  0.56464247,  0.71735609,
#         0.84147098,  0.93203909,  0.98544973,  0.9995736 ,  0.97384763,
#         0.90929743,  0.8084964 ,  0.67546318,  0.51550137,  0.33498815,
#         0.14112001, -0.05837414, -0.2555411 , -0.44252044, -0.61185789,
#        -0.7568025 , -0.87157577, -0.95160207, -0.993691  , -0.99616461,
#        -0.95892427, -0.88345466, -0.77276449, -0.63126664, -0.46460218,
#        -0.2794155 , -0.0830894 ,  0.1165492 ,  0.31154136,  0.49411335,
#         0.6569866 ,  0.79366786,  0.8987081 ,  0.96791967,  0.99854335,
#         0.98935825,  0.94073056,  0.85459891,  0.7343971 ,  0.58491719,
#         0.41211849,  0.22288991,  0.02477543, -0.17432678, -0.36647913,
#        -0.54402111])

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
ax1, ax2, ax3, ax4 = ax.flatten()
ax1.plot(x, y1)
ax1.set_xlim([-5, 5])
ax1.set_title('График y1')
ax2.plot(x, y2)
ax2.set_title('График y2')
ax3.plot(x, y3)
ax3.set_title('График y3')
ax4.plot(x, y4)
ax4.set_title('График y4')
fig.set_size_inches(8, 6)
plt.subplots_adjust(wspace=0.3, hspace=0.3)

# %% [markdown]
# # Task 4

# %%
# к сожелению не успел
